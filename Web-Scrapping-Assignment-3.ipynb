# %% [markdown]
# Q1 Write a python program which searches all the product under a particular product from
# www.amazon.in. The product name to be searched will be taken as input from user. For e.g. If
# user input is ‘guitar’. Then search for guitars

# %%
import selenium
import pandas as pd
from selenium import webdriver
import  time

# %%
#First we will connect to webdriver
driver=webdriver.Chrome(r'C:\Users\Nitin Singh Tatrari\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#Open the webpage with webdriver
driver.get('https://www.amazon.in/')

# %%
#Finding elements for search bar
search_job=driver.find_element_by_xpath("//input[@class='nav-input nav-progressive-attribute']")
search_job.send_keys('Laptop')

# %%
search_button=driver.find_element_by_xpath("//div[@class='nav-right']/div/span/input")
search_button.click()

# %% [markdown]
# Q2In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a dataframe and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“.

# %%
from selenium.common.exceptions import NoSuchElementException, ElementNotVisibleException,StaleElementReferenceException

# %%
# Getting href of all pages 
URL=[]
urls=driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none a-padding-base']/div[1]/ul[1]/li/a")
for i in urls:
    URL.append(i.get_attribute('href'))

# %%
URL[0:3]
# Out:
# ['https://www.amazon.in/s?k=Laptop&qid=1619717961&ref=sr_pg_1',
#  'https://www.amazon.in/s?k=Laptop&page=2&qid=1619717961&ref=sr_pg_2',
#  'https://www.amazon.in/s?k=Laptop&page=3&qid=1619717961&ref=sr_pg_3']

# %%
# We extract href of all the laptops in first three pages and store in list URL2
URL2=[]
for j in URL[0:3]:
    driver.get(j)
    url=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for i in url:
        URL2.append(i.get_attribute('href'))

# %%
#Create empty list to store scrapped data.
NAME=[]
PRICE=[]
DELI=[]
STOCK=[]
REV=[]
RATING=[]

# %%
#We extract desired data in text form and store it in respective lists.
for j in URL2:
    driver.get(j)
    try:
        name=driver.find_element_by_id("productTitle")
        NAME.append(name.text)
    except NoSuchElementException:
        NAME.append('--')
    try:
        price=driver.find_element_by_xpath("//td[@class='a-span12']/span[1]")
        PRICE.append(price.text)  
    except NoSuchElementException :
        PRICE.append('--') 
    try:
        deli=driver.find_element_by_id('ddmDeliveryMessage')
        DELI.append(deli.text)
    except NoSuchElementException : 
        DELI.append('--')
    try:
        stock=driver.find_element_by_id("availability")
        STOCK.append(stock.text)
    except NoSuchElementException :
        STOCK.append('--')
    try:
        rev=driver.find_element_by_id('acrCustomerReviewText')
        REV.append(rev.text)
    except NoSuchElementException:
        REV.append('--')
    try:
        driver.get(j)
        cl=driver.find_element_by_id('acrCustomerReviewText').click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        RATING.append(rating.text)
    except NoSuchElementException:
        RATING.append("--")

# %%
print(len(URL2),len(PRICE),len(DELI),len(STOCK),len(REV),len(RATING))
# Out:
# 54 54 54 54 54 54

# %% [markdown]
# All list have the same length

# %% [markdown]
# Now, we will copy the data from the list to Data Frame

# %%
import pandas as pd
Laptop=pd.DataFrame()

# %%
Laptop['NAME']=NAME[:]
Laptop['Price']=PRICE[:]
Laptop['Delivery Time']=DELI[:]
Laptop['Stock_Avaibility']=STOCK[:]
Laptop['Rating']=RATING[:]
Laptop['No._of_Reviews']=REV[:]
Laptop['Product_URL']=URL2[:]

# %%
Laptop
# Out:
#                                                  NAME        Price  \
# 0   MSI Bravo 15 Ryzen 7 4800H 15.6" FHD Gaming La...  ₹ 84,990.00
# 1   Acer Aspire 5 Intel Core i3 10th Generation 14...  ₹ 37,990.00
# 2   HP 15 Entry Level 15.6-inch (39.62 cms) HD Lap...  ₹ 23,990.00
# 3   AVITA Essential NE14A2INC433-CR 14-inch Laptop...  ₹ 17,990.00
# 4   Dell Inspiron 3502 15.6" (39.62 cms) HD Displa...           --
# 5   HP 15 Intel Pentium Gold 6405U Processor Entry...  ₹ 26,599.00
# 6   ASUS VivoBook 14 (2020) Intel Quad Core Pentiu...  ₹ 24,990.00
# 7   Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...  ₹ 29,885.00
# 8   HP 14 Ultra Thin & Light 14-inch Laptop (10th ...  ₹ 36,990.00
# 9   Asus X509MA-BR270T/ Silver/ Intel Celeron N402...  ₹ 25,678.00
# 10  Acer Swift 5 14" Full HD IPS Display with Touc...  ₹ 91,999.00
# 11  (Renewed) Fujitsu A573 Lifebook with Numeric K...  ₹ 19,990.00
# 12  Lenovo Ideapad Slim 3 AMD Athlon Silver 3050U ...  ₹ 28,990.00
# ...

# %%
driver.close()

# %% [markdown]
# Q4) Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
#First we will connect to webdriver
driver=webdriver.Chrome(r'C:\Users\Nitin Singh Tatrari\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#Open the webpage with webdriver
driver.get('https://www.flipkart.com/')

# %%
##Finding elements for search bar
search_sneaker=driver.find_element_by_xpath("//input[@class='_3704LK']")
search_sneaker.send_keys('smartphone')
search_button=driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()

# %%
#We will extract href of all smartphone on 1st page and store it in a list 'URL'
URL=[]
urls=driver.find_elements_by_xpath("//div[@class='_1AtVbE col-12-12']/div/div/div/a")
for i in urls:
    URL.append(i.get_attribute('href'))

# %%
#we will open 1st smartphone page to get all the necessary paths.
click=driver.find_element_by_xpath("//div[@class='_4rR01T']").click()

# %% [markdown]
# Now, We will create  empty lists to store the scrap data.

# %%
NAME=[]
COLOR=[]
RAM=[]
ROM=[]
PCAM=[]
SCAM=[]
SIZE=[]
DIM=[]
PRO=[]
CORE=[]
BAT=[]
PRICE=[]

# %% [markdown]
# We will extract datas in text form one by one from all href and store it in respective lists

# %%
for i in URL:
    driver.get(i)
    try:
        name=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg col-8-12']/div[2]/div[1]/div[1]/h1[1]/span")
        NAME.append(name.text)
    except NoSuchElementException:
        NAME.append('--')
    try:
        col=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li")
        COLOR.append(col.text)
    except NoSuchElementException:
        COLOR.append('--')
    try:
        click=driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
        ram=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('--')
    try:
        rom=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li")
        ROM.append(rom.text)
    except NoSuchElementException:
        ROM.append('--')
    try:
        p_cam=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li")
        PCAM.append(p_cam.text)
    except NoSuchElementException:
        PCAM.append('--')
    try:
        s_cam=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[2]/ul/li")
        SCAM.append(s_cam.text)
    except NoSuchElementException:
        SCAM.append('--')
    try:
        dis_sz=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li")
        SIZE.append(dis_sz.text)
    except NoSuchElementException:
        SIZE.append('--')
    try:
        dis_dim=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[2]/table/tbody/tr[2]/td[2]/ul/li")
        DIM.append(dis_dim.text)
    except NoSuchElementException:
        DIM.append('--')
    try:
        pro=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[3]/table/tbody/tr[2]/td[2]/ul/li")
        PRO.append(pro.text)
    except NoSuchElementException:
        PRO.append('--')
    try:
        pro_c=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[3]/table/tbody/tr[3]/td[2]/ul/li")
        CORE.append(pro_c.text)
    except NoSuchElementException:
        CORE.append('--')
    try:
        bat=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg']/div/div[1]/div[2]/div[1]/div[8]/table/tbody/tr/td[2]/ul/li")
        BAT.append(bat.text)
    except NoSuchElementException:
        BAT.append('--')
    try:
        price=driver.find_element_by_xpath("//div[@class='_1YokD2 _3Mn1Gg col-8-12']/div[2]/div[1]/div[4]/div[1]/div[1]/div[1]")
        PRICE.append(price.text)
    except NoSuchElementException:
        PRICE.append('--')

# %%
print(len(URL),len(NAME),len(COLOR),len(RAM),len(ROM),len(PCAM),len(SCAM),len(SIZE),len(DIM),len(PRO),len(CORE),len(BAT),len(PRICE))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24 24 24

# %% [markdown]
# Length of all the lists are same

# %% [markdown]
# We copy all the data from list to Data Frame

# %%
import pandas as pd
smph=pd.DataFrame()

# %%
smph['NAME']=NAME[:]
smph['COLOR']=COLOR[:]
smph['RAM']=RAM[:]
smph['ROM']=ROM[:]
smph['Primary_Camera']=PCAM[:]
smph['Secondary_Camera']=SCAM[:]
smph['DISPLAY_SIZE']=SIZE[:]
smph['DISPLA_RESOLUTION']=DIM[:]
smph['Processor']=PRO[:]
smph['CORE']=CORE[:]
smph['BATTERY']=BAT[:]
smph['PRICE']=PRICE[:]
smph['Product_URL']=URL[:]

# %%
smph
# Out:
#                                                  NAME              COLOR  \
# 0   Infinix Hot 10 Play (Morandi Green, 64 GB)  (4...      Morandi Green
# 1   Infinix Hot 10 Play (Aegean Blue, 64 GB)  (4 G...        Aegean Blue
# 2        REDMI 9i (Midnight Black, 64 GB)  (4 GB RAM)     Midnight Black
# 3   MOTOROLA G60 (Frosted Champagne, 128 GB)  (6 G...  Frosted Champagne
# 4              POCO M3 (Cool Blue, 64 GB)  (6 GB RAM)          Cool Blue
# 5           realme C20 (Cool Blue, 32 GB)  (2 GB RAM)          Cool Blue
# 6           realme C20 (Cool Grey, 32 GB)  (2 GB RAM)          Cool Grey
# 7         realme C21 (Cross Black, 32 GB)  (3 GB RAM)        Cross Black
# 8        realme C12 (Power Silver, 32 GB)  (3 GB RAM)       Power Silver
# 9          realme C12 (Power Blue, 32 GB)  (3 GB RAM)         Power Blue
# 10         realme C21 (Cross Blue, 64 GB)  (4 GB RAM)                 --
# 11         realme C21 (Cross Blue, 32 GB)  (3 GB RAM)         Cross Blue
# ...

# %%
driver.close()

# %% [markdown]
# Q6Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in.

# %%
#First we will connect to webdriver
driver=webdriver.Chrome(r'C:\Users\Nitin Singh Tatrari\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#Open the webpage with webdriver
driver.get('https://trak.in/')

# %%
#Clicking on 'Funding deal'option
search_job=driver.find_element_by_xpath("//ul[@class='main-menu menu clearfix bsm-initialized']/li[9]/a").click()

# %% [markdown]
# Now, We will create four empty list to store the scrap data.

# %%
DATE=[]
SNAME=[]
INDUS=[]
SUBV=[]
CITY=[]
INAME=[]
INTYPE=[]
AMT=[]

# %% [markdown]
# Now, we will scrap all the data for the month of July,2020 and store it in text form in respective lists

# %%
date=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[2]")
for i in date:
    DATE.append(i.text)
SUname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[3]")
for i in SUname:
    SNAME.append(i.text)
indus=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[4]")
for i in indus:
    INDUS.append(i.text)
sub=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[5]")
for i in sub:
    SUBV.append(i.text)
city=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[6]")
for i in city:
    CITY.append(i.text)
iname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[7]")
for i in iname:
    INAME.append(i.text)
intype=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[8]")
for i in intype:
    INTYPE.append(i.text)
amt=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-48 dataTable no-footer']/tbody/tr/td[9]")
for i in amt:
    AMT.append(i.text)

# %%
print(len(DATE),len(SNAME),len(INDUS),len(SUBV),len(CITY),len(INAME),len(INTYPE),len(AMT))
# Out:
# 10 10 10 10 10 10 10 10

# %% [markdown]
# All lists have the same length

# %% [markdown]
# We will extract all the data for August2020 in text form and store it in respective lists.In the loop we have kept element for clicking to next page

# %%
for j in range(1,3):
    date=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[2]")
    for i in date:
        if i.text is None:
            DATE.append('--')
        else:
            DATE.append(i.text)
    sname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[3]")
    for i in sname:
        if i.text is None:
            SNAME.append('--')
        else:
            SNAME.append(i.text)
    indus=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[4]")
    for i in indus:
        if i.text is None:
            INDUS.append('--')
        else:
            INDUS.append(i.text)
    subv=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[5]")
    for i in subv:
        if i.text is None:
            SUBV.append('--')
        else:
            SUBV.append(i.text)
    city=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[6]")
    for i in city:
        if i.text is None:
            CITY.append('--')
        else:
            CITY.append(i.text)
    iname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[7]")
    for i in iname:
        if i.text is None:
            INAME.append('--')
        else:
            INAME.append(i.text)
    intype=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[8]")
    for i in intype:
        if i.text is None:
            INTYPE.append('--')
        else:
            INTYPE.append(i.text)
        amt=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-49 dataTable no-footer']/tbody/tr/td[9]")
    for i in amt:
        if i.text is None:
            AMT.append('--')
        else:
            AMT.append(i.text)
    nextpg=driver.find_element_by_id('tablepress-49_next').click()

# %%
print(len(DATE),len(SNAME),len(INDUS),len(SUBV),len(CITY),len(INAME),len(INTYPE),len(AMT))
# Out:
# 22 22 22 22 22 22 22 22

# %% [markdown]
# All lists have the same length

# %% [markdown]
# We will extract all the data for August2020 in text form and store it in respective lists.

# %%
    date=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[2]")
    for i in date:
        if i.text is None:
            DATE.append('--')
        else:
            DATE.append(i.text)
    sname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[3]")
    for i in sname:
        if i.text is None:
            SNAME.append('--')
        else:
            SNAME.append(i.text)
    indus=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[4]")
    for i in indus:
        if i.text is None:
            INDUS.append('--')
        else:
            INDUS.append(i.text)
    subv=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[5]")
    for i in subv:
        if i.text is None:
            SUBV.append('--')
        else:
            SUBV.append(i.text)
    city=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[6]")
    for i in city:
        if i.text is None:
            CITY.append('--')
        else:
            CITY.append(i.text)
    iname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[7]")
    for i in iname:
        if i.text is None:
            INAME.append('--')
        else:
            INAME.append(i.text)
    intype=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[8]")
    for i in intype:
        if i.text is None:
            INTYPE.append('--')
        else:
            INTYPE.append(i.text)
    amt=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[9]")
    for i in amt:
        if i.text is None:
            AMT.append('--')
        else:
            AMT.append(i.text)

# %%
print(len(DATE),len(SNAME),len(INDUS),len(SUBV),len(CITY),len(INAME),len(INTYPE),len(AMT))
# Out:
# 32 32 32 32 32 32 32 32

# %% [markdown]
# All the lists have same length

# %% [markdown]
# Now we navigate to next ppage of September,2020

# %%
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import ElementClickInterceptedException

# %%
try:
    nextpg=driver.find_element_by_id('tablepress-50_next').click()
except ElementClickInterceptedException as e:
    print('Exception raised:',e)
# Out:
# Exception raised: Message: element click intercepted: Element <a class="paginate_button next" aria-controls="tablepress-50" data-dt-idx="1" tabindex="0" id="tablepress-50_next">...</a> is not clickable at point (1359, 10). Other element would receive the click: <div class="search-container close">...</div>
#   (Session info: chrome=90.0.4430.93)

# %% [markdown]
# Thus we will change to next page manually and again extract the data form the 2nd page of September,2020

# %%
date=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[2]")
for i in date:
    if i.text is None:
        DATE.append('--')
    else:
        DATE.append(i.text)
sname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[3]")
for i in sname:
    if i.text is None:
        SNAME.append('--')
    else:
        SNAME.append(i.text)
SNAME[20:]
indus=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[4]")
for i in indus:
    if i.text is None:
        INDUS.append('--')
    else:
        INDUS.append(i.text)
subv=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[5]")
for i in subv:
    if i.text is None:
        SUBV.append('--')
    else:
        SUBV.append(i.text)
city=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[6]")
for i in city:
    if i.text is None:
        CITY.append('--')
    else:
        CITY.append(i.text)
iname=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[7]")
for i in iname:
    if i.text is None:
        INAME.append('--')
    else:
        INAME.append(i.text)
intype=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[8]")
for i in intype:
    if i.text is None:
        INTYPE.append('--')
    else:
        INTYPE.append(i.text)
amt=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-50 dataTable no-footer']/tbody/tr/td[9]")
for i in amt:
    if i.text is None:
        AMT.append('--')
    else:
        AMT.append(i.text)

# %%
print(len(DATE),len(SNAME),len(INDUS),len(SUBV),len(CITY),len(INAME),len(INTYPE),len(AMT))
# Out:
# 33 33 33 33 33 33 33 33

# %% [markdown]
# All lists have same length

# %% [markdown]
# Now we will copy lists to Data Frame

# %%
import pandas as pd
funds=pd.DataFrame()

# %%
funds['DATE']=DATE[:]
funds['Startup_Name']=SNAME[:]
funds["Industry"]=INDUS[:]
funds["Sub-Vertical"]=SUBV[:]
funds["City"]=CITY[:]
funds["Investor's_Name"]=INAME[:]
funds["Investment_type"]=INTYPE[:]
funds["AMOUNT"]=AMT[:]

# %%
funds
# Out:
#           DATE               Startup_Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  03/08/2020                 CrowdPouch
# ...

# %%
driver.close()

# %% [markdown]
# Q7 Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
#First we will connect to webdriver
driver=webdriver.Chrome(r'C:\Users\Nitin Singh Tatrari\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#Open the webpage with webdriver
driver.get('https://www.digit.in/')

# %%
#Finding element for clicking
select=driver.find_element_by_xpath("//div[@class='header']/div[2]/div[4]/ul/li[3]/a").click()

# %%
select2=driver.find_element_by_xpath("//div[@class='col-sm-4']/div[2]/ul/li[10]/a").click()

# %% [markdown]
# Now, We will create empty list to store the scrap data.

# %%
NAME=[]
OS=[]
DIS=[]
PRO=[]
MEM=[]
WT=[]
DIM=[]
GPU=[]
PRICE=[]
DES=[]

# %% [markdown]
# We will extract the data in text form and store in respective lists

# %%
name=driver.find_elements_by_xpath("//div[@class='Center-block']/div[3]/table/tbody/tr/td[1]")
for i in name:
    if i.text is None:
        NAME.append("--")
    else:
        NAME.append(i.text)
        os=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
for i in os:
    if i.text is None:
        OS.append("--")
    else:
        OS.append(i.text)
dis=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
for i in dis:
    if i.text is None:
        DIS.append("--")
    else:
        DIS.append(i.text)
pro=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
for i in pro:
    if i.text is None:
        PRO.append("--")
    else:
        PRO.append(i.text)
mem=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
for i in mem:
    if i.text is None:
        MEM.append("--")
    else:
        MEM.append(i.text)
wt=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
for i in wt:
    if i.text is None:
        WT.append("--")
    else:
        WT.append(i.text)
dim=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for i in dim:
    if i.text is None:
        DIM.append("--")
    else:
        DIM.append(i.text)
gpu=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
for i in gpu:
    if i.text is None:
        GPU.append("--")
    else:
        GPU.append(i.text)
price=driver.find_elements_by_xpath("//td[@class='smprice']")
for i in price:
    if i.text is None:
        PRICE.append("--")
    else:
        PRICE.append(i.text)
des=driver.find_elements_by_xpath("//div[@class='Section-center']/p")
for i in des:
    if i.text is None:
        DES.append("--")
    else:
        DES.append(i.text)

# %%
print(len(NAME),len(OS),len(DIS),len(PRO),len(MEM),len(WT),len(DIM),len(GPU),len(PRICE),len(DES))
# Out:
# 7 7 7 7 7 7 7 7 7 7

# %% [markdown]
# All list have same length

# %% [markdown]
# We will copy the list to Data Frame

# %%
Laptop=pd.DataFrame()

# %%
Laptop['NAME']=NAME[:]
Laptop['OS']=OS[:]
Laptop["DISPLAY"]=DIS[:]
Laptop['PROCESSOR']=PRO[:]
Laptop['MEMORY']=MEM[:]
Laptop['WEIGHT']=WT[:]
Laptop['DIMENSION']=DIM[:]
Laptop['GPU']=GPU[:]
Laptop['PRICE']=PRICE[:]
Laptop['DESCRIPTION']=DES[:]

# %%
Laptop
# Out:
#                        NAME               OS              DISPLAY  \
# 0     Alienware Area 51M R2  Windows 10 Home  17.3" (1920 x 1080)
# 1          Alienware m15 R3  Windows 10 Home  15.6" (3840 x 2160)
# 2    ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 3     Asus ROG Zephyrus G14  Windows 10 Home    14" (1920 x 1080)
# 4          Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 5  ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 6      Acer Aspire 7 gaming  Windows 10 Home  15.6" (1920 x 1080)
#
#                                            PROCESSOR                  MEMORY  \
# 0   10th Generation Intel® Core™ i7-10700 | 2.90 GHz   1 TB SSD/16 GBGB DDR4
# 1       10th Generation Intel® Core™ i9-10980HK | NA   1 TB SSD/16 GBGB DDR4
# 2                      AMD Ryzen™ 9 5900HX | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 3               AMD 3rd Generation Ryzen 9 | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# ...

# %%
driver.close()
